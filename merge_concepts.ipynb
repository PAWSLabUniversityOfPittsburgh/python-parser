# %%
import pandas as pd

# %% [markdown]
# # Load Smart Content

# %%
quizpet = pd.read_csv('smart_learning_content_concepts_quizpet.csv')

quizpet.loc[:,'concept'] =  quizpet.loc[:,'component_name']
quizpet = quizpet[['content_name','concept']]

quizpet
# Out:
#                content_name                                            concept
# 0          q_py_while_loop2                      print_Int_While_Add_Assign_Lt
# 1           q_py_nested_if1                    print_Int_If_Gt_Assign_Tuple_Lt
# 2    q_py_comparison_logic1                          NotEq_print_Int_Assign_Lt
# 3              q_py_output2              _print_Int_Str_Attribute_Float_Assign
# 4       q_py_add_two_lists1           _List_print_Int_For_Attribute_Assign_Add
# ..                      ...                                                ...
# 101       q_py_dlinkedlist3  _List_Str_If_Attribute_IsNot_Add_NotEq_Nonetyp...
# 102   q_py_recursion_pascal  _List_print_FunctionDef_Int_For_Eq_If_Return_A...
# 103   q_py_demoquestion2_v2  FunctionDef_Int_GtE_Bool_If_Return_Gt_And_Sub_arg
# 104       q_py_obj_account1  _print_FunctionDef_Int_Dict_ClassDef_Attribute...
# 105        q_py_dict_square  _print_FunctionDef_Str_Mult_Dict_AugAssign_Ass...
#
# [106 rows x 2 columns]

# %%
pcex = pd.read_csv('smart_learning_content_concepts_pcex.csv')

pcex.loc[:,'concept'] =  pcex.loc[:,'component_name']
pcex = pcex[['content_name','concept']]

pcex
# Out:
#                    content_name  \
# 0                py_str_repeat2
# 1       py_concat_char_two_str1
# 2        py_adjacent_duplicates
# 3    py_search_list_total_count
# 4           py_adjacent_greater
# ..                          ...
# 118              py_score_dict1
# 119                    py_loan2
# 120       py_repeated_sequence1
# 121    py_fahrenheit_to_celsius
# 122              py_score_dict2
#
#                                                concept
# 0    _Int_Mult_Str_AugAssign_FunctionDef_Assign_pri...
# 1      Slice__Int_Str_FunctionDef_print_Add_Return_arg
# 2    _NotEq_Int_input_Str_While_USub_Assign_print_I...
# 3    _Int_Str_Float_AugAssign_FunctionDef_Assign_pr...
# 4    _NotEq_Int_input_Gt_Str_While_Assign_print_And_If
# ..                                                 ...
# 118  _Attribute_Int_In_Str_FunctionDef_Assign_Dict_...
# 119  _Attribute_Sub_Int_Mult_input_Str_FunctionDef_...
# 120                _Int_input_Str_Assign_print_Add_For
# 121           _Sub_Int_input_Mult_Str_Assign_print_Div
# 122  _Attribute_Int_In_Str_AugAssign_Div_FunctionDe...
#
# [123 rows x 2 columns]

# %%
parsons = pd.read_csv('smart_learning_content_concepts_parsons.csv')

parsons.loc[:,'concept'] =  parsons.loc[:,'component_name']
parsons = parsons[['content_name','concept']]

parsons
# Out:
#                           content_name  \
# 0                ps_python_comparisons
# 1              ps_python_divisible_by2
# 2   ps_python_iteration_multiplication
# 3        ps_python_recursive_factorial
# 4              ps_python_divisible_by3
# ..                                 ...
# 89             ps_python_list_reverse6
# 90                  ps_python_addition
# 91                  ps_simple_function
# 92       ps_python_list_of_remainders1
# 93               ps_python_sum_of_two1
#
#                                               concept
# 0                                 Assign_Gt_Int_print
# 1         _And_print_Mod_If_Int_Assign_Str_Eq_Add_For
# 2                  print_Lt_Int_Assign_Str_Mult_While
# 3          _arg_Sub_FunctionDef_Lt_If_Int_Return_Mult
# 4   _List_And_Attribute_print_Mod_If_Int_Assign_St...
# ..                                                ...
# 89                _List_Sub_print_Int_Assign_Mult_For
# 90                               Assign_Add_Int_print
# 91                             print_Str__FunctionDef
# 92  _List_Attribute_arg_FunctionDef_print_Mod_If_I...
# 93          And_Bool_arg_FunctionDef_If_Return_Eq_Add
#
# [94 rows x 2 columns]

# %%
examples = pd.read_csv('smart_learning_content_concepts_pcex_python_code.csv')

examples.loc[:,'concept'] =  examples.loc[:,'component_name']
examples = examples[['content_name','concept']]

examples
# Out:
#                  content_name  \
# 0                    py_input
# 1                py_list_fill
# 2                py_char_dict
# 3         py_str_repeat_chars
# 4          objects_classes_tv
# ..                        ...
# 66      py_single_linked_list
# 67          py_bmi_calculator
# 68         py_file_input_stat
# 69  py_sorting_insertion_sort
# 70                  py_digits
#
#                                               concept
# 0               _Str_print_GtE_input_While_Int_Assign
# 1       _print_List_Mult_Add_For_Int_Assign_Attribute
# 2   Str__print_If_Add_Dict_For_In_FunctionDef_AugA...
# 3   Str__print_Mult_Add_For_FunctionDef_AugAssign_...
# 4   _Str_print_Bool_Add_LtE_AugAssign_Assign_Retur...
# ..                                                ...
# 66  Str__print_NotEq_Add_AugAssign_Assign_Return_I...
# 67           _Str_print_Mult_input_Int_Assign_Div_Pow
# 68  Str__print_If_Add_For_Try_FunctionDef_AugAssig...
# 69  _print_List_Add_GtE_For_Lt_FunctionDef_Sub_Whi...
# 70             print_FloorDiv_While_Mod_Int_Assign_Gt
#
# [71 rows x 2 columns]

# %% [markdown]
# # merge files of smart content

# %%
content_name_urls = pd.read_csv('./readingmirror-data-files/smart_learning_content.csv')

content_name_urls = content_name_urls[['content_name','content_type','display_name','url']]

content_name_urls
# Out:
#                  content_name   content_type           display_name  \
# 0                    ps_hello        parsons                  Hello
# 1          ps_simple_function        parsons        Simple Function
# 2            ps_simple_params        parsons          Simple Params
# 3    ps_return_bigger_or_none        parsons  Return Bigger or None
# 4          ps_python_addition        parsons               Addition
# ..                        ...            ...                    ...
# 676                   pfe-6-9  readingmirror                pfe-6-9
# 677                    pfe-11  readingmirror                 pfe-11
# 678                    pfe-14  readingmirror                 pfe-14
# 679                   pfe-1-8  readingmirror                pfe-1-8
# 680          q_r_graph_theory              R           Graph Theory
#
#                                                    url
# 0    https://acos.cs.vt.edu/html/jsparsons/jsparson...
# 1    https://acos.cs.vt.edu/html/jsparsons/jsparson...
# 2    https://acos.cs.vt.edu/html/jsparsons/jsparson...
# 3    https://acos.cs.vt.edu/html/jsparsons/jsparson...
# 4    https://acos.cs.vt.edu/html/jsparsons/jsparson...
# ..                                                 ...
# 676  http://adapt2.sis.pitt.edu/ereader/reader/7/pf...
# 677  http://adapt2.sis.pitt.edu/ereader/reader/7/pf...
# 678  http://adapt2.sis.pitt.edu/ereader/reader/7/pf...
# 679  http://adapt2.sis.pitt.edu/ereader/reader/7/pf...
# 680  https://computing-explanation.netlify.app/grap...
#
# [681 rows x 4 columns]

# %%
content_name_urls.merge(quizpet,how='inner',on='content_name').to_csv('./out_merged_files/content_name_concept_urls_quizpet.csv', index=False)#.merge(textbook, how='inner',on='concept')

# %%
content_name_urls.merge(pcex,how='inner',on='content_name').to_csv('./out_merged_files/content_name_concept_urls_pcex.csv',index=False)#.merge(textbook, how='inner',on='concept')

# %%
content_name_urls.merge(parsons,how='inner',on='content_name').to_csv('./out_merged_files/content_name_concept_urls_parsons.csv',index=False)#.merge(textbook, how='inner',on='concept')

# %%
content_name_urls.merge(examples,how='inner',on='content_name').to_csv('./out_merged_files/content_name_concept_urls_examples.csv',index=False)#.merge(textbook, how='inner',on='concept')

# %% [markdown]
# # textbook sections write

# %%
textbook = pd.read_csv('smart_learning_content_section_page_numbers.csv')

textbook = textbook[['section_id','page_id','concept']]

textbook.loc[:,'section_id'] = textbook.loc[:,'section_id'].apply(lambda x: f"Section {'.'.join(x.split('-')[1:])}")

textbook = textbook.rename(columns={
    "page_id":"page_num"
})

textbook.head()
# Out:
#      section_id  page_num                                 concept
# 0   Section 6.6        70      Add_print_If_Eq_Int_For_Assign_Str
# 1  Section 6.11        74                Mod_Int_Assign_Str_Tuple
# 2   Section 6.5        70          Add_print_Slice_Int_Assign_Str
# 3   Section 6.9        71         _print_Attribute_Int_Assign_Str
# 4   Section 6.3        68  _While_Add_print_Lt_Int_For_Assign_Str

# %%
textbook = textbook.sort_values(by='page_num').reset_index()
textbook.loc[:,'concept_upto'] = textbook.loc[:,'concept']
textbook.to_csv('./out_merged_files/textbook_concepts_upto.csv')
textbook

# %% [markdown]
# # load merge files of smart content

# %%
content_name_urls = pd.read_csv('./out_merged_files/content_name_concept_urls.csv')
content_name_urls
# Out:
#                    content_name      content_type                display_name  \
# 0              q_py_arithmetic1  Tracing Problems           simple arithmetic
# 1              q_py_arithmetic2  Tracing Problems                  arithmetic
# 2                    q_py_swap1  Tracing Problems                        swap
# 3                 q_py_if_elif1  Tracing Problems                     if-elif
# 4          q_py_nested_if_elif1  Tracing Problems              nested if-elif
# ..                          ...               ...                         ...
# 336   py_sorting_insertion_sort          Examples              Insertion Sort
# 337     py_search_binary_search          Examples               Binary search
# 338     py_linkedlist_searching          Examples  Search in the linked list.
# 339          py_trees_traversal          Examples             Tree traversal.
# 340  py_trees_insert_binarytree          Examples       Inserting binary tree
#
#                                                    url  \
# 0    http://adapt2.sis.pitt.edu/quizpet/displayQuiz...
# 1    http://adapt2.sis.pitt.edu/quizpet/displayQuiz...
# 2    http://adapt2.sis.pitt.edu/quizpet/displayQuiz...
# 3    http://adapt2.sis.pitt.edu/quizpet/displayQuiz...
# 4    http://adapt2.sis.pitt.edu/quizpet/displayQuiz...
# ..                                                 ...
# 336  http://adapt2.sis.pitt.edu/pcex/index.html?lan...
# 337  http://adapt2.sis.pitt.edu/pcex/index.html?lan...
# 338  http://adapt2.sis.pitt.edu/pcex/index.html?lan...
# 339  http://adapt2.sis.pitt.edu/pcex/index.html?lan...
# 340  http://adapt2.sis.pitt.edu/pcex/index.html?lan...
#
#                                                concept
# 0                            print_Assign_FloorDiv_Sub
# 1                              Pow_Int_Mult_Assign_Add
# 2                                 Int_print_Assign_Add
# 3                       print_Int_Str_Eq_If_Assign_Mod
# 4                   print_Int_Str_GtE_Eq_If_Assign_Mod
# ..                                                 ...
# 336  _print_List_Add_GtE_For_Lt_FunctionDef_Sub_Whi...
# 337  _print_If_List_Bool_FloorDiv_Add_Lt_FunctionDe...
# 338  _Str_print_If_Eq_Bool_FunctionDef_While_Int_As...
# 339  Is__print_If_List_Add_Lt_FunctionDef_Int_Assig...
# 340  Is__Str_If_print_keyword_FunctionDef_Int_Assig...
#
# [341 rows x 5 columns]

# %% [markdown]
# # load textbook upto

# %%
textbook = pd.read_csv('./out_merged_files/textbook_concepts_upto.csv')
textbook
# Out:
#     Unnamed: 0  index    section_id  page_num  \
# 0            0     21   Section 2.1        19
# 1            1     20   Section 2.2        20
# 2            2     16   Section 2.5        22
# 3            3     19     Section 6        23
# 4            4     17   Section 2.7        23
# 5            5     13   Section 2.8        24
# 6            6     18   Section 2.9        24
# 7            7     14  Section 2.10        25
# 8            8     12  Section 2.11        26
# 9            9     15  Section 2.12        27
# 10          10     35   Section 3.1        31
# 11          11     28   Section 3.2        32
# 12          12     36   Section 3.3        32
# 13          13     29   Section 3.4        33
# 14          14     31   Section 3.5        34
# 15          15     34   Section 3.6        35
# 16          16     32   Section 3.7        36
# 17          17     30   Section 3.8        38
# 18          18     33   Section 3.9        39
# 19          19     39   Section 4.1        43
# 20          20     42   Section 4.2        43
# 21          21     44   Section 4.3        44
# 22          22     45   Section 4.4        45
# 23          23     40   Section 4.5        46
# 24          24     37   Section 4.6        47
# 25          25     41   Section 4.7        48
# 26          26     43  Section 4.10        51
# 27          27     38  Section 4.14        54
# 28          28     22   Section 5.1        57
# 29          29     25   Section 5.2        57
# 30          30     27   Section 5.3        58
# 31          31     23   Section 5.4        59
# 32          32     26   Section 5.5        60
# 33          33     24   Section 5.6        61
# 34          34      8   Section 6.1        67
# 35          35      4   Section 6.3        68
# 36          36     10   Section 6.2        68
# 37          37      7   Section 6.4        69
# 38          38      2   Section 6.5        70
# 39          39      0   Section 6.6        70
# 40          40      6   Section 6.7        71
# 41          41      3   Section 6.9        71
# 42          42      9   Section 6.8        71
# 43          43      5  Section 6.10        74
# 44          44      1  Section 6.11        74
# 45          45     11  Section 6.12        75
#
#                                               concept  \
# 0                                _print_Float_Int_Str
# 1                         _print_Float_Int_Assign_Str
# 2                     Mult_Add_Div_Sub_Int_Pow_Assign
# 3                                      Add_Assign_Int
# 4                            Add_Mult_Div_Sub_Int_Pow
# 5                       Mod_print_FloorDiv_Int_Assign
# 6                       Add_Mult_print_Int_Assign_Str
# 7                     _Add_print_input_Int_Assign_Str
# 8                                 Mult_Div_Assign_Int
# 9                         Mult_print_Float_For_Assign
# 10          _Bool_Lt_Gt_IsNot_Is_Eq_LtE_NotEq_Int_GtE
# 11                                 Bool_Lt_Gt_And_Int
# 12                 print_Lt_Gt_If_Int_Pass_Assign_Str
# 13                            Mod_print_If_Eq_Int_Str
# 14                              print_Lt_Gt_If_Eq_Str
# 15                         print_Lt_If_And_Eq_Int_Str
# 16  _Mult_print_ExceptHandler_Float_input_Div_Sub_...
# 17                    Gt_And_Div_NotEq_Int_Assign_GtE
# 18                                         Assign_Int
# 19                                               _Int
# 20                                               _Str
# 21                                _USub_Float_Int_Str
# 22  _Mult_print_Float_Attribute_Div_Int_alias_Assi...
# 23  _print_Attribute_Int_For_alias_Assign_List_Import
# 24                             FunctionDef__print_Str
# 25                                                NaN
# 26  _Add_print_Nonetype_Attribute_Return_Div_arg_I...
# 27                              FunctionDef_print_Str
# 28                                     Add_Assign_Int
# 29                  While_print_Gt_Sub_Int_Assign_Str
# 30  While_Bool_print_If_input_Eq_Break_Int_Assign_Str
# 31  While_Bool_print_If_input_Eq_Break_Int_Continu...
# 32                          print_For_Assign_Str_List
# 33  Add_print_Lt_Gt_Nonetype_If_Is_Or_arg_Int_Func...
# 34                               print_Assign_Str_Int
# 35             _While_Add_print_Lt_Int_For_Assign_Str
# 36                          _print_Sub_Int_Assign_Str
# 37                         print_Slice_Int_Assign_Str
# 38                     Add_print_Slice_Int_Assign_Str
# 39                 Add_print_If_Eq_Int_For_Assign_Str
# 40                                             In_Str
# 41                    _print_Attribute_Int_Assign_Str
# 42                   Add_print_Lt_Gt_If_Eq_Assign_Str
# 43          _Add_print_Slice_Attribute_Int_Assign_Str
# 44                           Mod_Int_Assign_Str_Tuple
# 45  _While_Bool_print_Gt_If_And_input_Eq_Attribute...
#
#                                          concept_upto
# 0                                _print_Float_Int_Str
# 1                         _print_Float_Int_Assign_Str
# 2                     Mult_Add_Div_Sub_Int_Pow_Assign
# 3                                      Add_Assign_Int
# 4                            Add_Mult_Div_Sub_Int_Pow
# 5                       Mod_print_FloorDiv_Int_Assign
# 6                       Add_Mult_print_Int_Assign_Str
# 7                     _Add_print_input_Int_Assign_Str
# 8                                 Mult_Div_Assign_Int
# 9                         Mult_print_Float_For_Assign
# 10          _Bool_Lt_Gt_IsNot_Is_Eq_LtE_NotEq_Int_GtE
# 11                                 Bool_Lt_Gt_And_Int
# 12                 print_Lt_Gt_If_Int_Pass_Assign_Str
# 13                            Mod_print_If_Eq_Int_Str
# 14                              print_Lt_Gt_If_Eq_Str
# 15                         print_Lt_If_And_Eq_Int_Str
# 16  _Mult_print_ExceptHandler_Float_input_Div_Sub_...
# 17                    Gt_And_Div_NotEq_Int_Assign_GtE
# 18                                         Assign_Int
# 19                                               _Int
# 20                                               _Str
# 21                                _USub_Float_Int_Str
# 22  _Mult_print_Float_Attribute_Div_Int_alias_Assi...
# 23  _print_Attribute_Int_For_alias_Assign_List_Import
# 24                             FunctionDef__print_Str
# 25                                                NaN
# 26  _Add_print_Nonetype_Attribute_Return_Div_arg_I...
# 27                              FunctionDef_print_Str
# 28                                     Add_Assign_Int
# 29                  While_print_Gt_Sub_Int_Assign_Str
# 30  While_Bool_print_If_input_Eq_Break_Int_Assign_Str
# 31  While_Bool_print_If_input_Eq_Break_Int_Continu...
# 32                          print_For_Assign_Str_List
# 33  Add_print_Lt_Gt_Nonetype_If_Is_Or_arg_Int_Func...
# 34                               print_Assign_Str_Int
# 35             _While_Add_print_Lt_Int_For_Assign_Str
# 36                          _print_Sub_Int_Assign_Str
# 37                         print_Slice_Int_Assign_Str
# 38                     Add_print_Slice_Int_Assign_Str
# 39                 Add_print_If_Eq_Int_For_Assign_Str
# 40                                             In_Str
# 41                    _print_Attribute_Int_Assign_Str
# 42                   Add_print_Lt_Gt_If_Eq_Assign_Str
# 43          _Add_print_Slice_Attribute_Int_Assign_Str
# 44                           Mod_Int_Assign_Str_Tuple
# 45  _While_Bool_print_Gt_If_And_input_Eq_Attribute...

# %%
for ind, row in textbook.iterrows():
    # if ind > 0:
        prev_concepts = []
        for j in range(ind):
            if not(pd.isna(textbook.loc[j,'concept'])):
                prev_concept = list(set(textbook.loc[j,'concept'].split('_')))
                prev_concepts.extend(prev_concept)
                # print(j,ind,textbook.loc[j,'concept'])
                # print(list(set(prev_concepts)))
        
        if not(pd.isna(row['concept'])):
            prev_concepts.extend(list(set(row['concept'].split('_'))))
            
        prev_concepts = list(set(prev_concepts))


        textbook.loc[ind,'concept_upto'] = '_'.join(prev_concepts)

textbook = textbook.rename(columns={
    "concept": "present_concept",
    "concept_upto": "concept"
})

textbook.sort_values(by='page_num',inplace=True)

textbook
# Out:
#     Unnamed: 0  index    section_id  page_num  \
# 0            0     21   Section 2.1        19
# 1            1     20   Section 2.2        20
# 2            2     16   Section 2.5        22
# 3            3     19     Section 6        23
# 4            4     17   Section 2.7        23
# 5            5     13   Section 2.8        24
# 6            6     18   Section 2.9        24
# 7            7     14  Section 2.10        25
# 8            8     12  Section 2.11        26
# 9            9     15  Section 2.12        27
# 10          10     35   Section 3.1        31
# 11          11     28   Section 3.2        32
# 12          12     36   Section 3.3        32
# 13          13     29   Section 3.4        33
# 14          14     31   Section 3.5        34
# 15          15     34   Section 3.6        35
# 16          16     32   Section 3.7        36
# 17          17     30   Section 3.8        38
# 18          18     33   Section 3.9        39
# 19          19     39   Section 4.1        43
# 20          20     42   Section 4.2        43
# 21          21     44   Section 4.3        44
# 22          22     45   Section 4.4        45
# 23          23     40   Section 4.5        46
# 24          24     37   Section 4.6        47
# 25          25     41   Section 4.7        48
# 26          26     43  Section 4.10        51
# 27          27     38  Section 4.14        54
# 28          28     22   Section 5.1        57
# 29          29     25   Section 5.2        57
# 30          30     27   Section 5.3        58
# 31          31     23   Section 5.4        59
# 32          32     26   Section 5.5        60
# 33          33     24   Section 5.6        61
# 34          34      8   Section 6.1        67
# 35          35      4   Section 6.3        68
# 36          36     10   Section 6.2        68
# 37          37      7   Section 6.4        69
# 38          38      2   Section 6.5        70
# 39          39      0   Section 6.6        70
# 40          40      6   Section 6.7        71
# 41          41      3   Section 6.9        71
# 42          42      9   Section 6.8        71
# 43          43      5  Section 6.10        74
# 44          44      1  Section 6.11        74
# 45          45     11  Section 6.12        75
#
#                                       present_concept  \
# 0                                _print_Float_Int_Str
# 1                         _print_Float_Int_Assign_Str
# 2                     Mult_Add_Div_Sub_Int_Pow_Assign
# 3                                      Add_Assign_Int
# 4                            Add_Mult_Div_Sub_Int_Pow
# 5                       Mod_print_FloorDiv_Int_Assign
# 6                       Add_Mult_print_Int_Assign_Str
# 7                     _Add_print_input_Int_Assign_Str
# 8                                 Mult_Div_Assign_Int
# 9                         Mult_print_Float_For_Assign
# 10          _Bool_Lt_Gt_IsNot_Is_Eq_LtE_NotEq_Int_GtE
# 11                                 Bool_Lt_Gt_And_Int
# 12                 print_Lt_Gt_If_Int_Pass_Assign_Str
# 13                            Mod_print_If_Eq_Int_Str
# 14                              print_Lt_Gt_If_Eq_Str
# 15                         print_Lt_If_And_Eq_Int_Str
# 16  _Mult_print_ExceptHandler_Float_input_Div_Sub_...
# 17                    Gt_And_Div_NotEq_Int_Assign_GtE
# 18                                         Assign_Int
# 19                                               _Int
# 20                                               _Str
# 21                                _USub_Float_Int_Str
# 22  _Mult_print_Float_Attribute_Div_Int_alias_Assi...
# 23  _print_Attribute_Int_For_alias_Assign_List_Import
# 24                             FunctionDef__print_Str
# 25                                                NaN
# 26  _Add_print_Nonetype_Attribute_Return_Div_arg_I...
# 27                              FunctionDef_print_Str
# 28                                     Add_Assign_Int
# 29                  While_print_Gt_Sub_Int_Assign_Str
# 30  While_Bool_print_If_input_Eq_Break_Int_Assign_Str
# 31  While_Bool_print_If_input_Eq_Break_Int_Continu...
# 32                          print_For_Assign_Str_List
# 33  Add_print_Lt_Gt_Nonetype_If_Is_Or_arg_Int_Func...
# 34                               print_Assign_Str_Int
# 35             _While_Add_print_Lt_Int_For_Assign_Str
# 36                          _print_Sub_Int_Assign_Str
# 37                         print_Slice_Int_Assign_Str
# 38                     Add_print_Slice_Int_Assign_Str
# 39                 Add_print_If_Eq_Int_For_Assign_Str
# 40                                             In_Str
# 41                    _print_Attribute_Int_Assign_Str
# 42                   Add_print_Lt_Gt_If_Eq_Assign_Str
# 43          _Add_print_Slice_Attribute_Int_Assign_Str
# 44                           Mod_Int_Assign_Str_Tuple
# 45  _While_Bool_print_Gt_If_And_input_Eq_Attribute...
#
#                                               concept
# 0                                _print_Int_Float_Str
# 1                         _Assign_print_Int_Float_Str
# 2    _Sub_Div_Assign_Mult_print_Pow_Add_Int_Float_Str
# 3    _Sub_Div_Assign_Mult_print_Pow_Add_Int_Float_Str
# 4    _Sub_Div_Assign_Mult_print_Pow_Add_Int_Float_Str
# 5   _Sub_Div_Assign_Mod_Mult_print_Pow_Add_Int_Flo...
# 6   _Sub_Div_Assign_Mod_Mult_print_Pow_Add_Int_Flo...
# 7   _Sub_Div_Assign_input_Mod_Mult_print_Pow_Add_I...
# 8   _Sub_Div_Assign_input_Mod_Mult_print_Pow_Add_I...
# 9   _Sub_Div_Assign_input_Mod_Mult_print_Pow_Add_I...
# 10  _Div_LtE_Assign_Str_IsNot_Eq_Mod_Mult_print_Ad...
# 11  _And_Div_LtE_Assign_Str_IsNot_Eq_Mod_Mult_prin...
# 12  _And_Div_LtE_Assign_Pass_Str_IsNot_If_Eq_Mod_M...
# 13  _And_Div_LtE_Assign_Pass_Str_IsNot_If_Eq_Mod_M...
# 14  _And_Div_LtE_Assign_Pass_Str_IsNot_If_Eq_Mod_M...
# 15  _And_Div_LtE_Assign_Pass_Str_IsNot_If_Eq_Mod_M...
# 16  _And_Div_LtE_Assign_Pass_Str_IsNot_If_Eq_Mod_M...
# 17  _And_Div_LtE_Assign_Pass_Str_IsNot_If_Eq_Mod_M...
# 18  _And_Div_LtE_Assign_Pass_Str_IsNot_If_Eq_Mod_M...
# 19  _And_Div_LtE_Assign_Pass_Str_IsNot_If_Eq_Mod_M...
# 20  _And_Div_LtE_Assign_Pass_Str_IsNot_If_Eq_Mod_M...
# 21  _And_Div_LtE_Assign_Pass_Str_IsNot_If_Eq_Mod_M...
# 22  _And_Div_LtE_Assign_alias_Attribute_Pass_Str_I...
# 23  _And_Div_LtE_Assign_alias_Attribute_Pass_Str_I...
# 24  _And_Div_LtE_Assign_alias_Attribute_Pass_Str_I...
# 25  _And_Div_LtE_Assign_alias_Attribute_Pass_Str_I...
# 26  _And_Div_LtE_Nonetype_Assign_alias_Attribute_P...
# 27  _And_Div_LtE_Nonetype_Assign_alias_Attribute_P...
# 28  _And_Div_LtE_Nonetype_Assign_alias_Attribute_P...
# 29  _And_Div_LtE_Nonetype_Assign_alias_Attribute_P...
# 30  _And_Div_LtE_Nonetype_Assign_alias_Attribute_P...
# 31  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 32  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 33  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 34  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 35  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 36  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 37  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 38  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 39  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 40  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 41  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 42  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 43  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 44  _And_Div_LtE_Nonetype_Assign_alias_Continue_Tu...
# 45  _And_Div_LtE_Nonetype_Assign_alias_Continue_Tu...

# %%
if False:
    for ind1, row1 in content_name_urls.iterrows():

        slc_concept = [x.lower() for x in set(row1['concept'].split('_'))] #if not(pd.isna(row1['concept'])) else []
        page_numbers = []
        section_ids = []
        prev_matched = False
        prev_match = count_match = 0
        ind =  textbook.shape[0]-1
        while ind > 0 and prev_match <= count_match:
            r_prev = textbook.loc[ind-1]
            r = textbook.loc[ind]
            bc_prev = [x.lower() for x in set(r_prev['concept'].split('_'))]
            bc = [x.lower() for x in set(r['concept'].split('_'))]

            for concept in slc_concept:
                for book_concept in bc: 
                    if concept == book_concept: count_match += 1
            
            for concept in slc_concept:
                for book_concept in bc_prev:
                    if concept == book_concept: prev_match += 1

            page_numbers.append(f"{r_prev['section_id']}-{r_prev['page_num']}")

        content_name_urls.loc[ind1,'page_numbers'] = ','.join([str(x) for x in set(page_numbers)])
        # content_name_urls.loc[ind1,'section_ids'] = ','.join([str(x) for x in set(section_ids)])

# %%
def get_page_nums(row,textbook):
    slc_concepts = [x.lower() for x in set(row['concept'].split('_'))] if not(pd.isna(row['concept'])) else []
    ind = 0
    page_nums = {}

    matched_concepts = {}
    while ind < textbook.shape[0]:
        row1 = textbook.loc[ind]
        book_concepts = [x.lower() for x in set(row1['concept'].split('_'))]
        match_count = 0

        for concept in book_concepts:
            if concept in slc_concepts: match_count += 1

        page_nums[f"{row1['section_id']}-{row1['page_num']}"] = match_count
        matched_concepts[f"{row1['section_id']}-{row1['page_num']}"] = row1['concept']

        ind += 1

    get_max_count = max(page_nums.values())

    return [(k,matched_concepts[k]) for k,v in page_nums.items() if v == get_max_count]


content_name_urls['book_match'] = content_name_urls.apply(get_page_nums,1,args=(textbook,))
content_name_urls = content_name_urls.explode('book_match')
content_name_urls['book_concepts'] = content_name_urls.apply(lambda x: x['book_match'][1],axis=1)
content_name_urls['page_numbers'] = content_name_urls.apply(lambda x: x['book_match'][0],axis=1)
content_name_urls[['content_name','content_type','display_name','url','page_numbers','book_concepts','concept']]   #,'section_ids']]
# Out:
#                    content_name      content_type           display_name  \
# 0              q_py_arithmetic1  Tracing Problems      simple arithmetic
# 0              q_py_arithmetic1  Tracing Problems      simple arithmetic
# 0              q_py_arithmetic1  Tracing Problems      simple arithmetic
# 0              q_py_arithmetic1  Tracing Problems      simple arithmetic
# 0              q_py_arithmetic1  Tracing Problems      simple arithmetic
# ..                          ...               ...                    ...
# 340  py_trees_insert_binarytree          Examples  Inserting binary tree
# 340  py_trees_insert_binarytree          Examples  Inserting binary tree
# 340  py_trees_insert_binarytree          Examples  Inserting binary tree
# 340  py_trees_insert_binarytree          Examples  Inserting binary tree
# 340  py_trees_insert_binarytree          Examples  Inserting binary tree
#
#                                                    url     page_numbers  \
# 0    http://adapt2.sis.pitt.edu/quizpet/displayQuiz...   Section 2.8-24
# 0    http://adapt2.sis.pitt.edu/quizpet/displayQuiz...   Section 2.9-24
# 0    http://adapt2.sis.pitt.edu/quizpet/displayQuiz...  Section 2.10-25
# 0    http://adapt2.sis.pitt.edu/quizpet/displayQuiz...  Section 2.11-26
# 0    http://adapt2.sis.pitt.edu/quizpet/displayQuiz...  Section 2.12-27
# ..                                                 ...              ...
# 340  http://adapt2.sis.pitt.edu/pcex/index.html?lan...   Section 6.9-71
# 340  http://adapt2.sis.pitt.edu/pcex/index.html?lan...   Section 6.8-71
# 340  http://adapt2.sis.pitt.edu/pcex/index.html?lan...  Section 6.10-74
# 340  http://adapt2.sis.pitt.edu/pcex/index.html?lan...  Section 6.11-74
# 340  http://adapt2.sis.pitt.edu/pcex/index.html?lan...  Section 6.12-75
#
#                                          book_concepts  \
# 0    _Sub_Div_Assign_Mod_Mult_print_Pow_Add_Int_Flo...
# 0    _Sub_Div_Assign_Mod_Mult_print_Pow_Add_Int_Flo...
# 0    _Sub_Div_Assign_input_Mod_Mult_print_Pow_Add_I...
# 0    _Sub_Div_Assign_input_Mod_Mult_print_Pow_Add_I...
# 0    _Sub_Div_Assign_input_Mod_Mult_print_Pow_Add_I...
# ..                                                 ...
# 340  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 340  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 340  _And_Div_LtE_Nonetype_Assign_alias_Continue_At...
# 340  _And_Div_LtE_Nonetype_Assign_alias_Continue_Tu...
# 340  _And_Div_LtE_Nonetype_Assign_alias_Continue_Tu...
#
#                                                concept
# 0                            print_Assign_FloorDiv_Sub
# 0                            print_Assign_FloorDiv_Sub
# 0                            print_Assign_FloorDiv_Sub
# 0                            print_Assign_FloorDiv_Sub
# 0                            print_Assign_FloorDiv_Sub
# ..                                                 ...
# 340  Is__Str_If_print_keyword_FunctionDef_Int_Assig...
# 340  Is__Str_If_print_keyword_FunctionDef_Int_Assig...
# 340  Is__Str_If_print_keyword_FunctionDef_Int_Assig...
# 340  Is__Str_If_print_keyword_FunctionDef_Int_Assig...
# 340  Is__Str_If_print_keyword_FunctionDef_Int_Assig...
#
# [7809 rows x 7 columns]

# %%
content_name_urls.loc[0,['page_numbers','concept']]
# Out:
#       page_numbers                    concept
# 0   Section 2.8-24  print_Assign_FloorDiv_Sub
# 0   Section 2.9-24  print_Assign_FloorDiv_Sub
# 0  Section 2.10-25  print_Assign_FloorDiv_Sub
# 0  Section 2.11-26  print_Assign_FloorDiv_Sub
# 0  Section 2.12-27  print_Assign_FloorDiv_Sub
# 0   Section 3.1-31  print_Assign_FloorDiv_Sub
# 0   Section 3.2-32  print_Assign_FloorDiv_Sub
# 0   Section 3.3-32  print_Assign_FloorDiv_Sub
# 0   Section 3.4-33  print_Assign_FloorDiv_Sub
# 0   Section 3.5-34  print_Assign_FloorDiv_Sub
# 0   Section 3.6-35  print_Assign_FloorDiv_Sub
# 0   Section 3.7-36  print_Assign_FloorDiv_Sub
# 0   Section 3.8-38  print_Assign_FloorDiv_Sub
# 0   Section 3.9-39  print_Assign_FloorDiv_Sub
# 0   Section 4.1-43  print_Assign_FloorDiv_Sub
# 0   Section 4.2-43  print_Assign_FloorDiv_Sub
# 0   Section 4.3-44  print_Assign_FloorDiv_Sub
# 0   Section 4.4-45  print_Assign_FloorDiv_Sub
# 0   Section 4.5-46  print_Assign_FloorDiv_Sub
# 0   Section 4.6-47  print_Assign_FloorDiv_Sub
# 0   Section 4.7-48  print_Assign_FloorDiv_Sub
# 0  Section 4.10-51  print_Assign_FloorDiv_Sub
# 0  Section 4.14-54  print_Assign_FloorDiv_Sub
# 0   Section 5.1-57  print_Assign_FloorDiv_Sub
# 0   Section 5.2-57  print_Assign_FloorDiv_Sub
# 0   Section 5.3-58  print_Assign_FloorDiv_Sub
# 0   Section 5.4-59  print_Assign_FloorDiv_Sub
# 0   Section 5.5-60  print_Assign_FloorDiv_Sub
# 0   Section 5.6-61  print_Assign_FloorDiv_Sub
# 0   Section 6.1-67  print_Assign_FloorDiv_Sub
# 0   Section 6.3-68  print_Assign_FloorDiv_Sub
# 0   Section 6.2-68  print_Assign_FloorDiv_Sub
# 0   Section 6.4-69  print_Assign_FloorDiv_Sub
# 0   Section 6.5-70  print_Assign_FloorDiv_Sub
# 0   Section 6.6-70  print_Assign_FloorDiv_Sub
# 0   Section 6.7-71  print_Assign_FloorDiv_Sub
# 0   Section 6.9-71  print_Assign_FloorDiv_Sub
# 0   Section 6.8-71  print_Assign_FloorDiv_Sub
# 0  Section 6.10-74  print_Assign_FloorDiv_Sub
# 0  Section 6.11-74  print_Assign_FloorDiv_Sub
# 0  Section 6.12-75  print_Assign_FloorDiv_Sub

# %%
content_name_urls.to_csv('./out_merged_files/content_name_concept_urls_page_numbers.csv',index=False)

# %%
content_name_urls = pd.read_csv('./out_merged_files/content_name_concept_urls_page_numbers.csv')

# %%
pdf_reader_list = content_name_urls[['content_name','content_type','display_name','url','page_numbers','concept']]#,'section_ids']]

# pdf_reader_list.loc[:,'page_numbers'] = pdf_reader_list['page_numbers'].str.split(',')
# pdf_reader_list_page = pdf_reader_list.explode('page_numbers')

# %%
pdf_reader_list_page = pdf_reader_list

pdf_reader_list_page.loc[:,'section_id'] = pdf_reader_list_page['page_numbers'].str.split('-').str[0]
pdf_reader_list_page.loc[:,'page_numbers'] = pdf_reader_list_page['page_numbers'].str.split('-').str[1]
# Out:
# /tmp/ipykernel_60743/4171809303.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pdf_reader_list_page.loc[:,'section_id'] = pdf_reader_list_page['page_numbers'].str.split('-').str[0]

# %%
pdf_reader_list_page
# Out:
#                     content_name      content_type           display_name  \
# 0               q_py_arithmetic1  Tracing Problems      simple arithmetic
# 1               q_py_arithmetic1  Tracing Problems      simple arithmetic
# 2               q_py_arithmetic1  Tracing Problems      simple arithmetic
# 3               q_py_arithmetic1  Tracing Problems      simple arithmetic
# 4               q_py_arithmetic1  Tracing Problems      simple arithmetic
# ...                          ...               ...                    ...
# 7804  py_trees_insert_binarytree          Examples  Inserting binary tree
# 7805  py_trees_insert_binarytree          Examples  Inserting binary tree
# 7806  py_trees_insert_binarytree          Examples  Inserting binary tree
# 7807  py_trees_insert_binarytree          Examples  Inserting binary tree
# 7808  py_trees_insert_binarytree          Examples  Inserting binary tree
#
#                                                     url page_numbers  \
# 0     http://adapt2.sis.pitt.edu/quizpet/displayQuiz...           24
# 1     http://adapt2.sis.pitt.edu/quizpet/displayQuiz...           24
# 2     http://adapt2.sis.pitt.edu/quizpet/displayQuiz...           25
# 3     http://adapt2.sis.pitt.edu/quizpet/displayQuiz...           26
# 4     http://adapt2.sis.pitt.edu/quizpet/displayQuiz...           27
# ...                                                 ...          ...
# 7804  http://adapt2.sis.pitt.edu/pcex/index.html?lan...           71
# 7805  http://adapt2.sis.pitt.edu/pcex/index.html?lan...           71
# 7806  http://adapt2.sis.pitt.edu/pcex/index.html?lan...           74
# 7807  http://adapt2.sis.pitt.edu/pcex/index.html?lan...           74
# 7808  http://adapt2.sis.pitt.edu/pcex/index.html?lan...           75
#
#                                                 concept    section_id
# 0                             print_Assign_FloorDiv_Sub   Section 2.8
# 1                             print_Assign_FloorDiv_Sub   Section 2.9
# 2                             print_Assign_FloorDiv_Sub  Section 2.10
# 3                             print_Assign_FloorDiv_Sub  Section 2.11
# 4                             print_Assign_FloorDiv_Sub  Section 2.12
# ...                                                 ...           ...
# 7804  Is__Str_If_print_keyword_FunctionDef_Int_Assig...   Section 6.9
# 7805  Is__Str_If_print_keyword_FunctionDef_Int_Assig...   Section 6.8
# 7806  Is__Str_If_print_keyword_FunctionDef_Int_Assig...  Section 6.10
# 7807  Is__Str_If_print_keyword_FunctionDef_Int_Assig...  Section 6.11
# 7808  Is__Str_If_print_keyword_FunctionDef_Int_Assig...  Section 6.12
#
# [7809 rows x 7 columns]

# %%
pdf_reader_list_page.to_csv('./out_merged_files/pdf_reader_list.csv',index=False)

# %%
pdf_reader_list_submitted = pd.read_csv('./out_merged_files/pdf_reader_list_submitted_version.csv')
updated_manually = pdf_reader_list.merge(pdf_reader_list_submitted,how='outer',
                      on = ['content_name','content_type','display_name','section_id'], 
                      indicator=True)

updated_manually = updated_manually[(updated_manually['_merge'] == 'left_only') & (updated_manually['section_id'] != '')]
updated_manually[['content_name','content_type','display_name','url_x']].to_csv('./out_merged_files/pdf_reader_list_manually_updated.csv',index=False)
updated_manually[['content_name','content_type','display_name','url_x']]
# Out:
#                     content_name      content_type           display_name  \
# 1               q_py_arithmetic1  Tracing Problems      simple arithmetic
# 2               q_py_arithmetic1  Tracing Problems      simple arithmetic
# 3               q_py_arithmetic1  Tracing Problems      simple arithmetic
# 4               q_py_arithmetic1  Tracing Problems      simple arithmetic
# 5               q_py_arithmetic1  Tracing Problems      simple arithmetic
# ...                          ...               ...                    ...
# 7804  py_trees_insert_binarytree          Examples  Inserting binary tree
# 7805  py_trees_insert_binarytree          Examples  Inserting binary tree
# 7806  py_trees_insert_binarytree          Examples  Inserting binary tree
# 7807  py_trees_insert_binarytree          Examples  Inserting binary tree
# 7808  py_trees_insert_binarytree          Examples  Inserting binary tree
#
#                                                   url_x
# 1     http://adapt2.sis.pitt.edu/quizpet/displayQuiz...
# 2     http://adapt2.sis.pitt.edu/quizpet/displayQuiz...
# 3     http://adapt2.sis.pitt.edu/quizpet/displayQuiz...
# 4     http://adapt2.sis.pitt.edu/quizpet/displayQuiz...
# 5     http://adapt2.sis.pitt.edu/quizpet/displayQuiz...
# ...                                                 ...
# 7804  http://adapt2.sis.pitt.edu/pcex/index.html?lan...
# 7805  http://adapt2.sis.pitt.edu/pcex/index.html?lan...
# 7806  http://adapt2.sis.pitt.edu/pcex/index.html?lan...
# 7807  http://adapt2.sis.pitt.edu/pcex/index.html?lan...
# 7808  http://adapt2.sis.pitt.edu/pcex/index.html?lan...
#
# [7580 rows x 4 columns]

# %%
updated_manually.to_json('./out_merged_files/pdf_reader_list_manually_updated.json')
